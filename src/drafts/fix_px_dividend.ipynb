# %%
import pandas as pd

# %%
stocks_t = pd.read_csv('crsp_example.csv').drop("Unnamed: 0", axis=1)

# %%
stocks_t
# Out:
#      ticker    open    high       low   close     volume      OPCL    pvCLCL  \
# 0       SPY  126.71  127.60  125.6969  127.05  138725200  0.002680  0.010338
# 1       IWM   78.94   80.02   78.7300   79.60   48877900  0.008326  0.017382
# 2       EEM   48.03   48.31   48.0300   48.10   40117700  0.001456  0.009613
# 3       TLT   93.20   94.31   92.9500   93.41   13799700  0.002251 -0.007544
# 4       USO   39.34   39.48   39.0000   39.05    4863200 -0.007399  0.001282
# ...     ...     ...     ...       ...     ...        ...       ...       ...
# 2940    ZMH   54.10   55.05   53.8400   54.97    1893700  0.015953  0.024031
# 2941    ZNH   31.11   31.24   30.9905   31.18      38600  0.002248  0.021960
# 2942    ZQK    5.13    5.47    5.1000    5.43    2196900  0.056833  0.071006
# 2943    ZTR    3.56    3.59    3.5600    3.56    1439900  0.000000  0.000000
# 2944     ZZ    2.96    3.00    2.9300    2.99     292500  0.010084  0.023973
#
# ...

# %%
stocks_t["currentAdjClose"] = (1 + stocks_t["pvCLCL"]) * stocks_t["prevAdjClose"]

# %%
stocks_t
# Out:
#      ticker    open    high       low   close     volume      OPCL    pvCLCL  \
# 0       SPY  126.71  127.60  125.6969  127.05  138725200  0.002680  0.010338
# 1       IWM   78.94   80.02   78.7300   79.60   48877900  0.008326  0.017382
# 2       EEM   48.03   48.31   48.0300   48.10   40117700  0.001456  0.009613
# 3       TLT   93.20   94.31   92.9500   93.41   13799700  0.002251 -0.007544
# 4       USO   39.34   39.48   39.0000   39.05    4863200 -0.007399  0.001282
# ...     ...     ...     ...       ...     ...        ...       ...       ...
# 2940    ZMH   54.10   55.05   53.8400   54.97    1893700  0.015953  0.024031
# 2941    ZNH   31.11   31.24   30.9905   31.18      38600  0.002248  0.021960
# 2942    ZQK    5.13    5.47    5.1000    5.43    2196900  0.056833  0.071006
# 2943    ZTR    3.56    3.59    3.5600    3.56    1439900  0.000000  0.000000
# 2944     ZZ    2.96    3.00    2.9300    2.99     292500  0.010084  0.023973
#
# ...
